# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# Out:
# Mon Jun 26 18:11:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.105.01   Driver Version: 515.105.01   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   27C    P8    13W / 230W |    831MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   29C    P8    15W / 230W |   2583MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   28C    P8    15W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   27C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   28C    P8    16W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   28C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   27C    P8    17W / 230W |   4854MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   28C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   4038055      C   ...onda3/envs/ste/bin/python      823MiB |
# |    1   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   4081187      C   ...3/envs/bytesep/bin/python     2575MiB |
# |    2   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A   1117035      C   ...hyun/anaconda3/bin/python     2699MiB |
# |    6   N/A  N/A   1117673      C   ...hyun/anaconda3/bin/python     2145MiB |
# |    7   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Hyperparams

# %%
n_mels = 16
n_outputs = 61
n_frames = 400

# %% [markdown]
# ### Model

# %%
from model.model_transformer_reg import Model
from utils.util import *
from tensorboardX import SummaryWriter

step = 0
device = 'cuda:0'

# Model
model = Model(in_dim=n_mels, h_dim=512, out_dim=n_outputs)
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
print('done')
# Out:
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lips/train06.26-1/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, model, _, optimizer = load(save_dir, 56389, model, None, optimizer)
# Out:
# total 0

# %% [markdown]
# ### Dataset

# %%
import os
from data.arkit_dataset import LipsDataset, CombinedDataset, CombinedCollate

root_dir = '/data/speech/digital_human/preprocessed/'
files = sorted([os.path.join(root_dir, file) for file in os.listdir(root_dir)])
print(len(files))

train_datasets = []
test_datasets = []

for file in files:
    print(file)
    dataset = LipsDataset(file, n_mels, n_frames)
    if '_10_' in file:
        test_datasets.append(dataset)
    else:
        train_datasets.append(dataset)
print(len(train_datasets), len(test_datasets))
# Out:
# 39
# /data/speech/digital_human/preprocessed/MH_ARKit_001_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_6_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_7_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_9_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_10_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_6_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_7_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_9_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_10_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_11_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_12_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_9_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_10_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_6_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_7_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_9_iPhone_raw.npy
# 36 3

# %%
train_loader = torch.utils.data.DataLoader(CombinedDataset(train_datasets), 
                                           num_workers=16, shuffle=True, batch_size=32, collate_fn=CombinedCollate())
test_loader = torch.utils.data.DataLoader(CombinedDataset(test_datasets), 
                                          num_workers=10, shuffle=True, batch_size=10, collate_fn=CombinedCollate())
print('done')
# Out:
# done

# %%
def logit(x):
    y = torch.clamp(x, min=1e-8, max=1 - 1e-8)
    y = torch.logit(y)
    return y

# %%
from IPython import display
import librosa.display
import matplotlib.pyplot as plt

isnan = False
while True:
    if isnan:
        break
    for batch in train_loader:
        inputs = torch.Tensor(batch['mel']).transpose(1, 2).to(device)
        targets = torch.Tensor(batch['blend']).transpose(1, 2).to(device)
        targets = logit(targets)
        
        model.train()
        model.zero_grad()
        outputs = model(inputs, targets)
        
        print(step)
        loss = 0
        for key in outputs.keys():
            if 'loss' in key:
                loss += outputs[key]
                print(key, outputs[key].item())
        if torch.isnan(loss):
            isnan = True
            break
        loss.backward()
        optimizer.step()
        print(step, loss.item())
        
        if step % 100 == 0:
            writer.add_scalar('train_loss', loss.item(), step)
        
        if step % 100 == 0:
            display.clear_output()
            
            losses = []
            for i, batch in enumerate(test_loader):
                if i >= 10:
                    break
                    
                inputs = torch.Tensor(batch['mel']).transpose(1, 2).to(device)
                targets = torch.Tensor(batch['blend']).transpose(1, 2).to(device)
                targets = logit(targets)

                model.eval()
                with torch.no_grad():
                    outputs = model(inputs, targets)
                    
                loss = 0
                for key in outputs.keys():
                    if 'loss' in key:
                        loss += outputs[key]
                print('test :', i, loss.item())
                losses.append(loss)        
            
            test_loss = torch.stack(losses).mean().item()
            print('test_loss :', test_loss)
            writer.add_scalar('test_loss', test_loss, step)
            
            plt.figure(figsize=[18, 4])
            librosa.display.specshow(targets[0].data.cpu().numpy(), cmap='magma')
            plt.show()

            plt.figure(figsize=[18, 4])
            librosa.display.specshow(outputs['y_pred'][0].data.cpu().numpy(), cmap='magma')
            plt.show()
            
            for i in [20, 37]:
                plt.figure(figsize=[18, 2])
                plt.title(str(i))
                plt.plot(targets[0].data.cpu().numpy()[i])
                plt.plot(outputs['y_pred'][0].data.cpu().numpy()[i])
                plt.show()

        if step % 1000 == 0:
            save(save_dir, step, model, None, optimizer)
    
        step += 1
# Out:
# test : 0 1.3078153133392334
# test : 1 1.32550048828125
# test : 2 1.4670966863632202
# test : 3 1.4279835224151611
# test : 4 1.3310441970825195
# test : 5 1.129260540008545
# test : 6 1.472706913948059
# test : 7 1.293781042098999
# test : 8 1.2190232276916504
# test : 9 1.3922992944717407
# test_loss : 1.3366512060165405
# 8901
# loss 1.1673504114151
# 8901 1.1673504114151
# 8902
# loss 1.1367921829223633
# 8902 1.1367921829223633
# 8903
# loss 1.418272614479065
# 8903 1.418272614479065
# 8904
# loss 1.0479823350906372
# 8904 1.0479823350906372
# 8905
# loss 1.2881721258163452
# 8905 1.2881721258163452
# 8906
# loss 1.214596152305603
# 8906 1.214596152305603
# 8907
# loss 1.1813230514526367
# 8907 1.1813230514526367
# 8908
# loss 1.2312076091766357
# 8908 1.2312076091766357
# 8909
# loss 1.1431115865707397
# 8909 1.1431115865707397
# 8910
# loss 1.1649051904678345
# 8910 1.1649051904678345
# 8911
# loss 1.147443175315857
# 8911 1.147443175315857
# 8912
# loss 1.2959953546524048
# 8912 1.2959953546524048
# 8913
# loss 1.2772724628448486
# 8913 1.2772724628448486
# 8914
# loss 1.2024480104446411
# 8914 1.2024480104446411
# 8915
# loss 1.1504660844802856
# 8915 1.1504660844802856
# 8916
# loss 1.272182822227478
# 8916 1.272182822227478
# 8917
# loss 1.233396053314209
# 8917 1.233396053314209
# 8918
# loss 1.2755725383758545
# 8918 1.2755725383758545
# 8919
# loss 1.180108666419983
# 8919 1.180108666419983
# 8920
# loss 1.1588042974472046
# 8920 1.1588042974472046
# 8921
# loss 1.1982030868530273
# 8921 1.1982030868530273
# 8922
# loss 1.2732034921646118
# 8922 1.2732034921646118
# 8923
# loss 1.1492036581039429
# 8923 1.1492036581039429
# 8924
# loss 1.074125051498413
# 8924 1.074125051498413
# 8925
# loss 1.1111054420471191
# 8925 1.1111054420471191
# 8926
# loss 1.1048177480697632
# 8926 1.1048177480697632
# 8927
# loss 1.3075374364852905
# 8927 1.3075374364852905
# 8928
# loss 1.0875543355941772
# 8928 1.0875543355941772
# 8929
# loss 1.1800813674926758
# 8929 1.1800813674926758
# 8930
# loss 1.05317223072052
# 8930 1.05317223072052
# 8931
# loss 1.3162845373153687
# 8931 1.3162845373153687
# 8932
# loss 1.1919931173324585
# 8932 1.1919931173324585
# 8933
# loss 1.2736332416534424
# 8933 1.2736332416534424
# 8934
# loss 1.0958757400512695
# 8934 1.0958757400512695
# 8935
# loss 1.189928650856018
# 8935 1.189928650856018
# 8936
# loss 1.3776594400405884
# 8936 1.3776594400405884
# 8937
# loss 1.32609224319458
# 8937 1.32609224319458
# 8938
# loss 1.3147201538085938
# 8938 1.3147201538085938
# 8939
# loss 1.2201297283172607
# 8939 1.2201297283172607
# 8940
# loss 1.3706856966018677
# 8940 1.3706856966018677
# 8941
# loss 1.2563897371292114
# 8941 1.2563897371292114
# 8942
# loss 1.2309534549713135
# 8942 1.2309534549713135
# 8943
# loss 1.2854126691818237
# 8943 1.2854126691818237
# 8944
# loss 1.058976173400879
# 8944 1.058976173400879
# 8945
# loss 1.1921801567077637
# 8945 1.1921801567077637
# 8946
# loss 1.2458703517913818
# 8946 1.2458703517913818
# 8947
# loss 1.2730292081832886
# 8947 1.2730292081832886

# %%
save(save_dir, step, model, None, optimizer)
# Out:
# saved /data/scpark/save/lips/train06.26-1/save_8737
