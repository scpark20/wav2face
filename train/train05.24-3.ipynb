# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="6"
# Out:
# Fri May 26 19:38:34 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.105.01   Driver Version: 515.105.01   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   26C    P8    14W / 230W |   2884MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   51C    P2   118W / 230W |  17677MiB / 24564MiB |     17%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   49C    P2    96W / 230W |  14547MiB / 24564MiB |     11%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   52C    P2   112W / 230W |  17983MiB / 24564MiB |     17%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   56C    P2   133W / 230W |  20349MiB / 24564MiB |     22%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   53C    P2   124W / 230W |  18575MiB / 24564MiB |     22%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   26C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   25C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2336909      C   ...3/envs/vspeech/bin/python     2515MiB |
# |    0   N/A  N/A   3179769      C   ...onda3/envs/ste/bin/python      361MiB |
# |    1   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   1228692      C   ...3/envs/vspeech/bin/python    17669MiB |
# |    2   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   1577592      C   ...3/envs/vspeech/bin/python    14539MiB |
# |    3   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   2613533      C   ...3/envs/vspeech/bin/python    17975MiB |
# |    4   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2969687      C   ...3/envs/vspeech/bin/python    20341MiB |
# |    5   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   3096022      C   ...3/envs/vspeech/bin/python    18567MiB |
# |    6   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      3580      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Hyperparams

# %%
n_mels = 8
n_outputs = 61
n_frames = 400
sr = 24000
fps = 30
train_csv_files = ['/Storage/speech/face/rvh_viseme2_1_iPhone_raw_30fps.csv',
                   '/Storage/speech/face/rvh_viseme2_2_iPhone_raw_30fps.csv',
                   '/Storage/speech/face/rvh_viseme2_3_iPhone_raw_30fps.csv',
                   '/Storage/speech/face/rvh_viseme2_4_iPhone_raw_30fps.csv',
                  ]
train_wav_files = ['/Storage/speech/face/rvh_viseme2_1_iPhone.wav',
                   '/Storage/speech/face/rvh_viseme2_2_iPhone.wav',
                   '/Storage/speech/face/rvh_viseme2_3_iPhone.wav',
                   '/Storage/speech/face/rvh_viseme2_4_iPhone.wav',
                  ]

test_csv_files = ['/Storage/speech/face/MySlate_6_박수철의_iPhone_30fps.csv']
test_wav_files = ['/Storage/speech/face/MySlate_6_박수철의_iPhone.wav']

# %% [markdown]
# ### Model

# %%
from model.model_vqvae import Model
from utils.util import *
from tensorboardX import SummaryWriter

step = 0
device = 'cuda:0'

# Model
model = Model(in_dim=n_mels, out_dim=n_outputs, K=16, latent_dim=128)
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
print('done')
# Out:
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lips/train05.24-3/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if False:
    step, model, _, optimizer = load(save_dir, 1000, model, None, optimizer)
# Out:
# total 0

# %%
import torch
from data.dataset import LipsDataset, Collate

dataset = LipsDataset(train_wav_files, train_csv_files, n_frames, n_mels=n_mels, sr=sr, fps=fps)
print('train dataset :', len(dataset))
train_loader = torch.utils.data.DataLoader(dataset, num_workers=1, shuffle=True, batch_size=8, 
                                           collate_fn=Collate(n_frames, n_mels))
print(train_loader)

dataset = LipsDataset(test_wav_files, test_csv_files, n_frames, n_mels=n_mels, sr=sr, fps=fps)
print('test dataset :', len(dataset))
test_loader = torch.utils.data.DataLoader(dataset, num_workers=1, shuffle=True, batch_size=8,
                                           collate_fn=Collate(n_frames, n_mels))
print(test_loader)
# Out:
# train dataset : 28308
# <torch.utils.data.dataloader.DataLoader object at 0x7f87862e37f0>
# test dataset : 1413
# <torch.utils.data.dataloader.DataLoader object at 0x7f8716126220>

# %%
def preprocess(x):
    return torch.log10(x+1) * 10

# %%
from IPython import display
import librosa.display
import matplotlib.pyplot as plt

isnan = False
while True:
    if isnan:
        break
    for batch in train_loader:
        inputs = batch['inputs'].transpose(1, 2).to(device)
        targets = batch['outputs'].transpose(1, 2).to(device)
        targets = preprocess(targets)
        
        model.train()
        model.zero_grad()
        outputs = model(inputs, targets)
        
        print(step)
        loss = 0
        for key in outputs.keys():
            if 'loss' in key:
                loss += outputs[key]
                print(key, outputs[key].item())
        if torch.isnan(loss):
            isnan = True
            break
        loss.backward()
        optimizer.step()
        print(step, loss.item())
        
        if step % 100 == 0:
            writer.add_scalar('train_loss', loss.item(), step)
        
        if step % 100 == 0:
            display.clear_output()
            
            losses = []
            for i, batch in enumerate(test_loader):
                if i >= 10:
                    break
                    
                inputs = batch['inputs'].transpose(1, 2).to(device)
                targets = batch['outputs'].transpose(1, 2).to(device)
                targets = preprocess(targets)

                model.eval()
                with torch.no_grad():
                    outputs = model(inputs, targets)
                    
                loss = 0
                for key in outputs.keys():
                    if 'loss' in key:
                        loss += outputs[key]
                print('test :', i, loss.item())
                losses.append(loss)        
            
            test_loss = torch.stack(losses).mean().item()
            print('test_loss :', test_loss)
            writer.add_scalar('test_loss', test_loss, step)

        if step % 1000 == 0:
            save(save_dir, step, model, None, optimizer)
    
        step += 1
# Out:
# test : 0 5.177490711212158
# test : 1 5.17063570022583
# test : 2 5.269093990325928
# test : 3 5.301322937011719
# test : 4 5.237942218780518
# test : 5 5.35686731338501
# test : 6 5.158825397491455
# test : 7 5.294137477874756
# test : 8 5.333480358123779
# test : 9 5.224009037017822
# test_loss : 5.25238037109375
# 4101
# auto_encoding_loss 0.032544348388910294
# commit_loss 0.01419934444129467
# zi_prediction_loss 0.47786498069763184
# 4101 0.5246086716651917
# 4102
# auto_encoding_loss 0.03392971679568291
# commit_loss 0.014050749130547047
# zi_prediction_loss 0.5034300088882446
# 4102 0.5514104962348938
# 4103
# auto_encoding_loss 0.033825017511844635
# commit_loss 0.014151062816381454
# zi_prediction_loss 0.504743754863739
# 4103 0.5527198314666748
# 4104
# auto_encoding_loss 0.03348485380411148
# commit_loss 0.0153043232858181
# zi_prediction_loss 0.4886641800403595
# 4104 0.5374533534049988
# 4105
# auto_encoding_loss 0.03134307265281677
# commit_loss 0.014694973826408386
# zi_prediction_loss 0.5100514888763428
# 4105 0.5560895204544067
# 4106
# auto_encoding_loss 0.03514503687620163
# commit_loss 0.014196811243891716
# zi_prediction_loss 0.497396856546402
# 4106 0.5467386841773987
# 4107
# auto_encoding_loss 0.035539641976356506
# commit_loss 0.015264262445271015
# zi_prediction_loss 0.5022990703582764
# 4107 0.553102970123291
# 4108
# auto_encoding_loss 0.032747503370046616
# commit_loss 0.015498568303883076
# zi_prediction_loss 0.4571823179721832
# 4108 0.5054283738136292
# 4109
# auto_encoding_loss 0.0337376669049263
# commit_loss 0.015247832983732224
# zi_prediction_loss 0.48959195613861084
# 4109 0.5385774374008179
# 4110
# auto_encoding_loss 0.03219721466302872
# commit_loss 0.014086584560573101
# zi_prediction_loss 0.4844784438610077
# 4110 0.530762255191803
# 4111
# auto_encoding_loss 0.032513201236724854
# commit_loss 0.01393298339098692
# zi_prediction_loss 0.502183198928833
# 4111 0.5486294031143188
# 4112
# auto_encoding_loss 0.031318262219429016
# commit_loss 0.0138414166867733
# zi_prediction_loss 0.4918040335178375
# 4112 0.536963701248169
# 4113
# auto_encoding_loss 0.037523604929447174
# commit_loss 0.01502544991672039
# zi_prediction_loss 0.571199357509613
# 4113 0.6237484216690063
# 4114
# auto_encoding_loss 0.03296985849738121
# commit_loss 0.014779684133827686
# zi_prediction_loss 0.46798962354660034
# 4114 0.5157391428947449
# 4115
# auto_encoding_loss 0.03390839323401451
# commit_loss 0.015242258086800575
# zi_prediction_loss 0.45880866050720215
# 4115 0.5079593062400818
# 4116
# auto_encoding_loss 0.03311909735202789
# commit_loss 0.014210464432835579
# zi_prediction_loss 0.4789721667766571
# 4116 0.5263017416000366
# 4117
# auto_encoding_loss 0.031751733273267746
# commit_loss 0.01472504809498787
# zi_prediction_loss 0.5006340742111206
# 4117 0.5471108555793762
# 4118
# auto_encoding_loss 0.03160425275564194
# commit_loss 0.01388404332101345
# zi_prediction_loss 0.48517051339149475
# 4118 0.5306588411331177
# 4119
# auto_encoding_loss 0.03810593858361244
# commit_loss 0.01753096655011177
# zi_prediction_loss 0.5765718221664429
# 4119 0.6322087049484253
# 4120
# auto_encoding_loss 0.03549583628773689
# commit_loss 0.013288137502968311
# zi_prediction_loss 0.48848259449005127
# 4120 0.5372665524482727
# 4121
# auto_encoding_loss 0.0343174934387207
# commit_loss 0.015214486978948116
# zi_prediction_loss 0.6026429533958435
# 4121 0.6521749496459961
# 4122
# auto_encoding_loss 0.03340810909867287
# commit_loss 0.014477617107331753
# zi_prediction_loss 0.4815472364425659
# 4122 0.5294329524040222
# 4123
# auto_encoding_loss 0.03421134129166603
# commit_loss 0.013857794925570488
# zi_prediction_loss 0.5071614980697632
# 4123 0.5552306175231934
# 4124
# auto_encoding_loss 0.03332718089222908
# commit_loss 0.01421468984335661
# zi_prediction_loss 0.5697450041770935
# 4124 0.6172868609428406
# 4125
# auto_encoding_loss 0.03466472774744034
# commit_loss 0.014396567828953266
# zi_prediction_loss 0.5506988763809204
# 4125 0.5997601747512817
# 4126
# auto_encoding_loss 0.034245043992996216
# commit_loss 0.013963124714791775
# zi_prediction_loss 0.5218279361724854
# 4126 0.5700361132621765
# 4127
# auto_encoding_loss 0.03444299474358559
# commit_loss 0.015431995503604412
# zi_prediction_loss 0.5334272980690002
# 4127 0.5833022594451904
# 4128
# auto_encoding_loss 0.03465380519628525
# commit_loss 0.01655125617980957
# zi_prediction_loss 0.5338080525398254
# 4128 0.5850130915641785
# 4129
# auto_encoding_loss 0.031551167368888855
# commit_loss 0.013418295420706272
# zi_prediction_loss 0.47155675292015076
# 4129 0.5165262222290039
# 4130
# auto_encoding_loss 0.03426482155919075
# commit_loss 0.016526175662875175
# zi_prediction_loss 0.4815835952758789
# 4130 0.5323746204376221
# 4131
# auto_encoding_loss 0.034769173711538315
# commit_loss 0.014675538055598736
# zi_prediction_loss 0.5450767874717712
# 4131 0.5945215225219727
# 4132
# auto_encoding_loss 0.03268219903111458
# commit_loss 0.014534158632159233
# zi_prediction_loss 0.5250256061553955
# 4132 0.5722419619560242
# 4133
# auto_encoding_loss 0.034299880266189575
# commit_loss 0.015994833782315254
# zi_prediction_loss 0.5113592743873596
# 4133 0.5616539716720581
# 4134
# auto_encoding_loss 0.03193888068199158
# commit_loss 0.01450403779745102
# zi_prediction_loss 0.5361639261245728
# 4134 0.582606852054596
# 4135
# auto_encoding_loss 0.03396519273519516
# commit_loss 0.015427770093083382
# zi_prediction_loss 0.4747147858142853
# 4135 0.5241077542304993
# 4136
# auto_encoding_loss 0.031048836186528206
# commit_loss 0.015014172531664371
# zi_prediction_loss 0.45598000288009644
# 4136 0.5020430088043213
# 4137
# auto_encoding_loss 0.03364210203289986
# commit_loss 0.01499031763523817
# zi_prediction_loss 0.5355439186096191
# 4137 0.5841763615608215
# 4138
# auto_encoding_loss 0.03269321843981743
# commit_loss 0.013821282424032688
# zi_prediction_loss 0.4557534456253052
# 4138 0.5022679567337036
# 4139
# auto_encoding_loss 0.03602270781993866
# commit_loss 0.015246476978063583
# zi_prediction_loss 0.47351062297821045
# 4139 0.5247797966003418
# 4140
# auto_encoding_loss 0.035049259662628174
# commit_loss 0.01448209211230278
# zi_prediction_loss 0.4809296131134033
# 4140 0.5304609537124634
# 4141
# auto_encoding_loss 0.03189285099506378
# commit_loss 0.013140114024281502
# zi_prediction_loss 0.45056307315826416
# 4141 0.4955960512161255
# 4142
# auto_encoding_loss 0.0350901260972023
# commit_loss 0.014249193482100964
# zi_prediction_loss 0.45851942896842957
# 4142 0.5078587532043457
# 4143
# auto_encoding_loss 0.036054328083992004
# commit_loss 0.015671459957957268
# zi_prediction_loss 0.5271373391151428
# 4143 0.5788631439208984
# 4144
# auto_encoding_loss 0.0330364853143692
# commit_loss 0.013355495408177376
# zi_prediction_loss 0.5060043334960938
# 4144 0.552396297454834
# 4145
# auto_encoding_loss 0.03400237485766411
# commit_loss 0.01451095100492239
# zi_prediction_loss 0.48842498660087585
# 4145 0.5369383096694946
# 4146
# auto_encoding_loss 0.0362294539809227
# commit_loss 0.016644595190882683
# zi_prediction_loss 0.5073525905609131
# 4146 0.5602266192436218
# 4147
# auto_encoding_loss 0.032228682190179825
# commit_loss 0.01523820124566555
# zi_prediction_loss 0.4612106680870056
# 4147 0.5086775422096252
# 4148
# auto_encoding_loss 0.0328521765768528
# commit_loss 0.013899722136557102
# zi_prediction_loss 0.5122142434120178
# 4148 0.5589661598205566
# 4149
# auto_encoding_loss 0.03263554722070694
# commit_loss 0.014013279229402542
# zi_prediction_loss 0.5047258138656616
# 4149 0.551374614238739
# 4150
# auto_encoding_loss 0.03541973605751991
# commit_loss 0.014247402548789978
# zi_prediction_loss 0.5170190334320068
# 4150 0.5666861534118652
# 4151
# auto_encoding_loss 0.03223530575633049
# commit_loss 0.013653063215315342
# zi_prediction_loss 0.5353701710700989
# 4151 0.5812585353851318
# 4152
# auto_encoding_loss 0.03508075326681137
# commit_loss 0.015223831869661808
# zi_prediction_loss 0.5240264534950256
# 4152 0.5743310451507568
# 4153
# auto_encoding_loss 0.03167196363210678
# commit_loss 0.014508657157421112
# zi_prediction_loss 0.5158843398094177
# 4153 0.5620649456977844
# 4154
# auto_encoding_loss 0.03203558176755905
# commit_loss 0.013911192305386066
# zi_prediction_loss 0.476689875125885
# 4154 0.5226366519927979
# 4155
# auto_encoding_loss 0.03586908057332039
# commit_loss 0.014140352606773376
# zi_prediction_loss 0.5060317516326904
# 4155 0.5560411810874939
# 4156
# auto_encoding_loss 0.03381253033876419
# commit_loss 0.014570148661732674
# zi_prediction_loss 0.47867003083229065
# 4156 0.5270527005195618
# 4157
# auto_encoding_loss 0.03226485848426819
# commit_loss 0.013209875673055649
# zi_prediction_loss 0.518524706363678
# 4157 0.5639994144439697
# 4158
# auto_encoding_loss 0.03447716310620308
# commit_loss 0.01453304011374712
# zi_prediction_loss 0.4823058247566223
# 4158 0.5313160419464111
# 4159
# auto_encoding_loss 0.03471828252077103
# commit_loss 0.01421065628528595
# zi_prediction_loss 0.4838577210903168
# 4159 0.5327866673469543
# 4160
# auto_encoding_loss 0.0321192592382431
# commit_loss 0.013345185667276382
# zi_prediction_loss 0.4879230856895447
# 4160 0.5333875417709351
# 4161
# auto_encoding_loss 0.03057291731238365
# commit_loss 0.013443058356642723
# zi_prediction_loss 0.5052249431610107
# 4161 0.5492409467697144
# 4162
# auto_encoding_loss 0.03250075504183769
# commit_loss 0.015609064139425755
# zi_prediction_loss 0.4817618131637573
# 4162 0.5298716425895691
# 4163
# auto_encoding_loss 0.031765323132276535
# commit_loss 0.013135994784533978
# zi_prediction_loss 0.4584120810031891
# 4163 0.503313422203064
# 4164
# auto_encoding_loss 0.03143935278058052
# commit_loss 0.01281314343214035
# zi_prediction_loss 0.44785788655281067
# 4164 0.49211037158966064
# 4165
# auto_encoding_loss 0.03184980899095535
# commit_loss 0.013209501281380653
# zi_prediction_loss 0.4800184667110443
# 4165 0.525077760219574
# 4166
# auto_encoding_loss 0.030876995995640755
# commit_loss 0.013583092018961906
# zi_prediction_loss 0.45440658926963806
# 4166 0.4988666772842407
# 4167
# auto_encoding_loss 0.03025306761264801
# commit_loss 0.012130281887948513
# zi_prediction_loss 0.43192631006240845
# 4167 0.47430965304374695
# 4168
# auto_encoding_loss 0.03625601530075073
# commit_loss 0.014316151849925518
# zi_prediction_loss 0.5832037925720215
# 4168 0.6337759494781494
# 4169
# auto_encoding_loss 0.03514520451426506
# commit_loss 0.015381612814962864
# zi_prediction_loss 0.47466492652893066
# 4169 0.5251917243003845
# 4170
# auto_encoding_loss 0.03417758271098137
# commit_loss 0.014811525121331215
# zi_prediction_loss 0.4582841098308563
# 4170 0.5072731971740723
# 4171
# auto_encoding_loss 0.03583710268139839
# commit_loss 0.015793852508068085
# zi_prediction_loss 0.4480559527873993
# 4171 0.4996868968009949
# 4172
# auto_encoding_loss 0.03759912773966789
# commit_loss 0.014584679156541824
# zi_prediction_loss 0.5306163430213928
# 4172 0.5828001499176025
# 4173
# auto_encoding_loss 0.03516095504164696
# commit_loss 0.013871908187866211
# zi_prediction_loss 0.47432488203048706
# 4173 0.5233577489852905
# 4174
# auto_encoding_loss 0.03231857717037201
# commit_loss 0.013425411656498909
# zi_prediction_loss 0.5050820708274841
# 4174 0.5508260726928711
# 4175
# auto_encoding_loss 0.033580709248781204
# commit_loss 0.013219520449638367
# zi_prediction_loss 0.4970821738243103
# 4175 0.543882429599762
# 4176
# auto_encoding_loss 0.03263736143708229
# commit_loss 0.014853836968541145
# zi_prediction_loss 0.4487913250923157
# 4176 0.49628251791000366
# 4177
# auto_encoding_loss 0.034783314913511276
# commit_loss 0.013641385361552238
# zi_prediction_loss 0.5252258777618408
# 4177 0.573650598526001
# 4178
# auto_encoding_loss 0.03186395764350891
# commit_loss 0.01449334342032671
# zi_prediction_loss 0.4681604504585266
# 4178 0.5145177245140076
# 4179
# auto_encoding_loss 0.03561476245522499
# commit_loss 0.013428020291030407
# zi_prediction_loss 0.5050671100616455
# 4179 0.5541098713874817
# 4180
# auto_encoding_loss 0.03525526449084282
# commit_loss 0.013802220113575459
# zi_prediction_loss 0.5505581498146057
# 4180 0.5996156334877014
# 4181
# auto_encoding_loss 0.03299594670534134
# commit_loss 0.013399941846728325
# zi_prediction_loss 0.5879809856414795
# 4181 0.6343768835067749
# 4182
# auto_encoding_loss 0.031802915036678314
# commit_loss 0.013160914182662964
# zi_prediction_loss 0.5145512223243713
# 4182 0.5595150589942932
# 4183
# auto_encoding_loss 0.034825876355171204
# commit_loss 0.014482686296105385
# zi_prediction_loss 0.49532538652420044
# 4183 0.5446339249610901
# 4184
# auto_encoding_loss 0.03361060097813606
# commit_loss 0.01415263395756483
# zi_prediction_loss 0.553830623626709
# 4184 0.6015938520431519
# 4185
# auto_encoding_loss 0.033799950033426285
# commit_loss 0.013657965697348118
# zi_prediction_loss 0.4812060594558716
# 4185 0.5286639928817749
# 4186
# auto_encoding_loss 0.03124081902205944
# commit_loss 0.013109824620187283
# zi_prediction_loss 0.4940471649169922
# 4186 0.5383977890014648
# 4187
# auto_encoding_loss 0.03512178361415863
# commit_loss 0.014843486249446869
# zi_prediction_loss 0.5075672268867493
# 4187 0.5575324892997742
# 4188
# auto_encoding_loss 0.03147977590560913
# commit_loss 0.013121738098561764
# zi_prediction_loss 0.4988989233970642
# 4188 0.5435004234313965
# 4189
# auto_encoding_loss 0.032277703285217285
# commit_loss 0.012686283327639103
# zi_prediction_loss 0.5425204634666443
# 4189 0.5874844789505005
# 4190
# auto_encoding_loss 0.03129557520151138
# commit_loss 0.013868500478565693
# zi_prediction_loss 0.4916411340236664
# 4190 0.5368052124977112
# 4191
# auto_encoding_loss 0.03297100216150284
# commit_loss 0.01330143865197897
# zi_prediction_loss 0.4776092767715454
