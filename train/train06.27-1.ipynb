# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Tue Jun 27 22:56:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.105.01   Driver Version: 515.105.01   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   28C    P8    17W / 230W |    475MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   31C    P5    55W / 230W |   2229MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   34C    P2    57W / 230W |    601MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 30%   34C    P8    23W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 30%   58C    P2   179W / 230W |   6983MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 30%   39C    P8    56W / 230W |   8423MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   28C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   27C    P8    21W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2672545      C   ...onda3/envs/ste/bin/python      467MiB |
# |    1   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A   1399825      C   ...hyun/anaconda3/bin/python     2221MiB |
# |    2   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A   1452014      C   ...nda3/envs/ste2/bin/python      597MiB |
# |    3   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2135967      C   ...nda3/envs/ste2/bin/python     6975MiB |
# |    5   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2679286      C   ...nda3/envs/ste2/bin/python     8415MiB |
# |    6   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      3840      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Hyperparams

# %%
n_mels = 16
n_outputs = 61
n_frames = 400

# %% [markdown]
# ### Model

# %%
from model.model_conv_flow import Model
from utils.util import *
from tensorboardX import SummaryWriter

step = 0
device = 'cuda:0'

# Model
model = Model(channels=n_outputs, cond_channels=n_mels, hidden_channels=128, n_layers=4)
model = model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
print('done')
# Out:
# done

# %% [markdown]
# ### Load

# %%
save_dir = '/data/scpark/save/lips/train06.27-1/'
# !mkdir -p $save_dir
# !ls -lt $save_dir

writer = SummaryWriter(save_dir)

if True:
    step, model, _, optimizer = load(save_dir, 21664, model, None, optimizer)
# Out:
# total 96272
# -rw-rw-r-- 1 scpark scpark      40  6월 27 22:56 events.out.tfevents.1687873969.GPUSVR01
# -rw-rw-r-- 1 scpark scpark      40  6월 27 22:56 events.out.tfevents.1687873984.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 22:51 save_21664
# -rw-rw-r-- 1 scpark scpark   10525  6월 27 22:49 events.out.tfevents.1687847687.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 22:09 save_21000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 21:12 save_20000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 20:25 save_19000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 19:44 save_18000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 19:04 save_17000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 18:25 save_16000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 17:42 save_15000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 16:59 save_14000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 16:28 save_13000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 16:01 save_12000
# -rw-rw-r-- 1 scpark scpark 4283893  6월 27 15:36 save_11000
# -rw-rw-r-- 1 scpark scpark       0  6월 27 15:34 events.out.tfevents.1687847680.GPUSVR01
# -rw-rw-r-- 1 scpark scpark   10987  6월 27 07:11 events.out.tfevents.1687806565.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 06:51 save_10000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 06:34 save_9000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 06:16 save_8000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 05:58 save_7000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 05:41 save_6000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 05:22 save_5000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 05:04 save_4000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 04:47 save_3000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 04:33 save_2000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 04:22 save_1000
# -rw-rw-r-- 1 scpark scpark 4283829  6월 27 04:11 save_0
# -rw-rw-r-- 1 scpark scpark     131  6월 27 04:08 events.out.tfevents.1687806362.GPUSVR01
# -rw-rw-r-- 1 scpark scpark      40  6월 27 04:05 events.out.tfevents.1687806207.GPUSVR01
# loaded /data/scpark/save/lips/train06.27-1/save_21664

# %% [markdown]
# ### Dataset

# %%
import os
from data.arkit_dataset import LipsDataset, CombinedDataset, CombinedCollate

root_dir = '/data/speech/digital_human/preprocessed/'
files = sorted([os.path.join(root_dir, file) for file in os.listdir(root_dir)])
print(len(files))

train_datasets = []
test_datasets = []

for file in files:
    print(file)
    dataset = LipsDataset(file, n_mels, n_frames)
    if '_10_' in file:
        test_datasets.append(dataset)
    else:
        train_datasets.append(dataset)
print(len(train_datasets), len(test_datasets))
# Out:
# 39
# /data/speech/digital_human/preprocessed/MH_ARKit_001_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_6_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_7_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_001_9_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_10_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_6_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_7_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_002_9_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_10_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_11_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_12_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_003_9_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_10_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_1_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_2_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_3_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_4_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_5_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_6_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_7_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_8_iPhone_raw.npy
# /data/speech/digital_human/preprocessed/MH_ARKit_004_9_iPhone_raw.npy
# 36 3

# %%
train_loader = torch.utils.data.DataLoader(CombinedDataset(train_datasets), 
                                           num_workers=16, shuffle=True, batch_size=32, collate_fn=CombinedCollate())
test_loader = torch.utils.data.DataLoader(CombinedDataset(test_datasets), 
                                          num_workers=10, shuffle=True, batch_size=10, collate_fn=CombinedCollate())
print('done')
# Out:
# done

# %%
from IPython import display
import librosa.display
import matplotlib.pyplot as plt

isnan = False
while True:
    if isnan:
        break
    for batch in train_loader:
        inputs = torch.Tensor(batch['mel']).transpose(1, 2).to(device)
        targets = torch.Tensor(batch['blend']).transpose(1, 2).to(device)
        
        model.train()
        model.zero_grad()
        outputs = model(targets, inputs)
        
        print(step)
        loss = 0
        for key in outputs.keys():
            if 'loss' in key:
                loss += outputs[key]
                print(key, outputs[key].item())
        if torch.isnan(loss):
            isnan = True
            break
        loss.backward()
        optimizer.step()
        print(step, loss.item())
        
        if step % 100 == 0:
            writer.add_scalar('train_loss', loss.item(), step)
        
        if step % 100 == 0:
            display.clear_output()
            
            losses = []
            for i, batch in enumerate(test_loader):
                if i >= 10:
                    break
                    
                inputs = torch.Tensor(batch['mel']).transpose(1, 2).to(device)
                targets = torch.Tensor(batch['blend']).transpose(1, 2).to(device)

                model.eval()
                with torch.no_grad():
                    outputs = model(targets, inputs)
                    
                loss = 0
                for key in outputs.keys():
                    if 'loss' in key:
                        loss += outputs[key]
                print('test :', i, loss.item())
                losses.append(loss)        
            
            test_loss = torch.stack(losses).mean().item()
            print('test_loss :', test_loss)
            writer.add_scalar('test_loss', test_loss, step)
            
            plt.figure(figsize=[18, 4])
            librosa.display.specshow(targets[0].data.cpu().numpy(), cmap='magma')
            plt.show()
            
            model.eval()
            with torch.no_grad():
                y_pred = model.inference(inputs)

            plt.figure(figsize=[18, 4])
            librosa.display.specshow(y_pred[0].data.cpu().numpy(), cmap='magma')
            plt.show()
            
            for i in [20, 37]:
                plt.figure(figsize=[18, 2])
                plt.title(str(i))
                plt.plot(targets[0].data.cpu().numpy()[i])
                plt.plot(y_pred[0].data.cpu().numpy()[i])
                plt.show()

        if step % 1000 == 0:
            save(save_dir, step, model, None, optimizer)
    
        step += 1
# Out:
# test : 0 -3.7646584510803223
# test : 1 -3.7764148712158203
# test : 2 -3.7886948585510254
# test : 3 -3.7715020179748535
# test : 4 -3.8300583362579346
# test : 5 -3.8170478343963623
# test : 6 -3.741473436355591
# test : 7 -3.766953229904175
# test : 8 -3.6769471168518066
# test : 9 -3.8134963512420654
# test_loss : -3.7747247219085693
# 21701
# loss -3.8081226348876953
# 21701 -3.8081226348876953
# 21702
# loss -3.8060190677642822
# 21702 -3.8060190677642822
# 21703
# loss -3.8007395267486572
# 21703 -3.8007395267486572
# 21704
# loss -3.8562631607055664
# 21704 -3.8562631607055664
# 21705
# loss -3.6887381076812744
# 21705 -3.6887381076812744
# 21706
# loss -3.797825813293457
# 21706 -3.797825813293457
# 21707
# loss -3.810405731201172
# 21707 -3.810405731201172
# 21708
# loss -3.8341970443725586
# 21708 -3.8341970443725586
# 21709
# loss -3.8229615688323975
# 21709 -3.8229615688323975
# 21710
# loss -3.8149123191833496
# 21710 -3.8149123191833496
# 21711
# loss -3.8019189834594727
# 21711 -3.8019189834594727
# 21712
# loss -3.804213523864746
# 21712 -3.804213523864746
# 21713
# loss -3.82643723487854
# 21713 -3.82643723487854
# 21714
# loss -3.7905805110931396
# 21714 -3.7905805110931396
# 21715
# loss -3.76837158203125
# 21715 -3.76837158203125
# 21716
# loss -3.7873971462249756
# 21716 -3.7873971462249756
# 21717
# loss -3.7835540771484375
# 21717 -3.7835540771484375
# 21718
# loss -3.7263379096984863
# 21718 -3.7263379096984863
# 21719
# loss -3.809896469116211
# 21719 -3.809896469116211
# 21720
# loss -3.8194901943206787
# 21720 -3.8194901943206787
# 21721
# loss -3.785702705383301
# 21721 -3.785702705383301
# 21722
# loss -3.806589126586914
# 21722 -3.806589126586914
# 21723
# loss -3.8023390769958496
# 21723 -3.8023390769958496
# 21724
# loss -3.809241533279419
# 21724 -3.809241533279419
# 21725
# loss -3.7763776779174805
# 21725 -3.7763776779174805
# 21726
# loss -3.7999460697174072
# 21726 -3.7999460697174072
# 21727
# loss -3.8089418411254883
# 21727 -3.8089418411254883
# 21728
# loss -3.811703681945801
# 21728 -3.811703681945801
# 21729
# loss -3.786553382873535
# 21729 -3.786553382873535
# 21730
# loss -3.705087900161743
# 21730 -3.705087900161743
# 21731
# loss -3.8170459270477295
# 21731 -3.8170459270477295
# 21732
# loss -3.810832977294922
# 21732 -3.810832977294922
# 21733
# loss -3.8124704360961914
# 21733 -3.8124704360961914
# 21734
# loss -3.8293042182922363
# 21734 -3.8293042182922363
# 21735
# loss -3.8186793327331543
# 21735 -3.8186793327331543
# 21736
# loss -3.800381660461426
# 21736 -3.800381660461426
# 21737
# loss -3.8131542205810547
# 21737 -3.8131542205810547
# 21738
# loss -3.842533588409424
# 21738 -3.842533588409424
# 21739
# loss -3.8303709030151367
# 21739 -3.8303709030151367
# 21740
# loss -3.847217082977295
# 21740 -3.847217082977295
# 21741
# loss -3.817805767059326
# 21741 -3.817805767059326
# 21742
# loss -3.8177506923675537
# 21742 -3.8177506923675537
# 21743
# loss -3.8276615142822266
# 21743 -3.8276615142822266

# %%
save(save_dir, step, model, None, optimizer)

# %%
print('done')
