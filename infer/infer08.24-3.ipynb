# %%
import os
os.chdir('../')

import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os

# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Sat Aug 26 06:25:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A5000    Off  | 00000000:1B:00.0 Off |                    0 |
# | 30%   28C    P2    53W / 230W |  15546MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A5000    Off  | 00000000:1C:00.0 Off |                  Off |
# | 30%   57C    P2   210W / 230W |  14560MiB / 24564MiB |     52%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A5000    Off  | 00000000:1D:00.0 Off |                  Off |
# | 30%   57C    P2   181W / 230W |  13336MiB / 24564MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A5000    Off  | 00000000:1E:00.0 Off |                  Off |
# | 32%   61C    P2   219W / 230W |  12262MiB / 24564MiB |     79%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA RTX A5000    Off  | 00000000:89:00.0 Off |                  Off |
# | 34%   63C    P2   205W / 230W |  12262MiB / 24564MiB |     92%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA RTX A5000    Off  | 00000000:8A:00.0 Off |                  Off |
# | 33%   63C    P2   204W / 230W |  12262MiB / 24564MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA RTX A5000    Off  | 00000000:8B:00.0 Off |                  Off |
# | 30%   24C    P8    18W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA RTX A5000    Off  | 00000000:8C:00.0 Off |                  Off |
# | 30%   23C    P8    17W / 230W |      8MiB / 24564MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A   2122730      C   ...nda3/envs/ste2/bin/python     4274MiB |
# |    0   N/A  N/A   2193728      C   ...nda3/envs/ste2/bin/python     4400MiB |
# |    0   N/A  N/A   2245525      C   ...nda3/envs/ste2/bin/python     3432MiB |
# |    0   N/A  N/A   2371546      C   ...nda3/envs/ste2/bin/python     3432MiB |
# |    1   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A    403234      C   ...onda3/envs/ste/bin/python     2298MiB |
# |    1   N/A  N/A   1092078      C   ...nda3/envs/ste2/bin/python    12254MiB |
# |    2   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A     36805      C   ...onda3/envs/ste/bin/python     1074MiB |
# |    2   N/A  N/A   1095054      C   ...nda3/envs/ste2/bin/python    12254MiB |
# |    3   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A   1096072      C   ...nda3/envs/ste2/bin/python    12254MiB |
# |    4   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A   2297059      C   ...nda3/envs/ste2/bin/python    12254MiB |
# |    5   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A   2320839      C   ...nda3/envs/ste2/bin/python    12254MiB |
# |    6   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# |    7   N/A  N/A      3595      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Hyperparams

# %%
n_mels = 1024
n_outputs = 61
n_frames = 400

# %%
from model.model_glowtts_sid import Model
from utils.util import *
from tensorboardX import SummaryWriter

step = 0
device = 'cuda:0'

# Model
model = Model(in_dim=n_mels, enc_hidden_dim=256, out_dim=61, dec_hidden_dim=256)
model = model.to(device)
model.eval()
print('done')
# Out:
# done

# %%
# !ls -lt /data/scpark/save/lips/train08.24-3/
# Out:
# total 10342096
# -rw-rw-r-- 1 scpark scpark     16167  8월 27 06:05 events.out.tfevents.1692881674.GPUSVR01
# -rw-rw-r-- 1 scpark scpark 661888901  8월 27 04:41 save_170000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 27 01:10 save_160000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 21:43 save_150000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 18:13 save_140000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 14:35 save_130000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 11:07 save_120000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 07:34 save_110000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 04:01 save_100000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 26 00:35 save_90000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 21:10 save_80000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 17:43 save_70000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 14:03 save_60000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 10:43 save_50000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 07:25 save_40000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 04:06 save_30000
# -rw-rw-r-- 1 scpark scpark 661888901  8월 25 00:48 save_20000

# %%
path = '/data/scpark/save/lips/train08.24-3/save_170000'
checkpoint = torch.load(path, map_location=torch.device('cpu'))    
model.load_state_dict(checkpoint['model_state_dict'], strict=True)
print('done')
# Out:
# done

# %%
# !ls -lS samples/
# Out:
# total 2056
# -rw-rw-r-- 1 scpark scpark 462057  8월 26 02:14 comparison.ipynb
# -rw-rw-r-- 1 scpark scpark 384572  8월 21 14:36 reg_dvae_flow.ipynb
# -rw-rw-r-- 1 scpark scpark 157264  8월 25 15:20 infer08.14-3.npy
# -rw-rw-r-- 1 scpark scpark 157264  8월 25 15:02 infer08.21-1.npy
# -rw-rw-r-- 1 scpark scpark 157264  8월 26 06:25 infer08.24-1.npy
# -rw-rw-r-- 1 scpark scpark 157264  8월 26 06:25 infer08.24-2.npy
# -rw-rw-r-- 1 scpark scpark 157264  8월 25 15:02 infer08.24-3.npy
# -rw-rw-r-- 1 scpark scpark 157264  8월 26 01:07 infer08.24-4.npy
# -rw-rw-r-- 1 scpark scpark 157264  8월 26 01:07 infer08.24-5.npy
# -rw-rw-r-- 1 scpark scpark 136236  8월 24 11:15 good.wav

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

processor = Wav2Vec2Processor.from_pretrained("kresnik/wav2vec2-large-xlsr-korean")
wav2vec = Wav2Vec2ForCTC.from_pretrained("kresnik/wav2vec2-large-xlsr-korean").to(device)
print('done')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# done

# %%
import matplotlib.pyplot as plt
#wav_file = '/Storage/speech/tts/kaist-audio-book/wav/남1_동화1/1181.wav'
#wav_file = '/Storage/speech/tts/kaist-audio-book/wav/여1_동화1/1181.wav'
wav_file = 'samples/good.wav'
wav, _ = librosa.load(wav_file, sr=16000, res_type='polyphase')
wav = wav / max(abs(wav))

plt.plot(wav)
plt.ylim([-1, 1])
plt.show()

# %%
def get_blendshape(wav, sid, layer=24):
    with torch.no_grad():
        wav = torch.Tensor(wav).unsqueeze(0).to(device)
        states = wav2vec(wav, output_hidden_states=True).hidden_states[layer].transpose(1, 2)
        states = F.interpolate(states, scale_factor=3/5, mode='linear').detach()
    sid = torch.Tensor([sid]).long().to(device)
    with torch.no_grad():
        y = model.inference(states, sid=sid, temperature=0.1)
        y = torch.clamp(y, min=0, max=1)
    y = y[0].data.cpu().numpy()
    return y
    
ys = []
for sid in range(1, 8):
    y = get_blendshape(wav, sid)
    ys.append(y)
    
ys = np.stack(ys)
print(ys.shape)

np.save('samples/infer08.24-3.npy', ys)
print('done')
# Out:
# (7, 61, 92)
# done

# %%
names = ['jeewonPark', 'jinwooOh', 'kyuchulLee', 'kyuseokKim', 'nohsikPark', 'soochulPark', 'yehunHwang']
targets = [(17, 'JawOpen'), (20, 'MouthPucker'), (23, 'MouthSmileLeft'), (37, 'MouthLowerDownLeft')]

for target in targets:
    plt.figure(figsize=[18, 2])
    plt.title(str(target[0]) + ' : ' + target[1])
    for i in range(len(ys)):
        plt.plot(ys[i][target[0]], label=names[i], linewidth=2)
    plt.grid()
    plt.legend()
    plt.show()
